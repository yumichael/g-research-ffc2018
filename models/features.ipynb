# %%
from common import *

# %%
feats = x1feats
dhlin = dh[feats]
dhlog = np.log(dhlin.replace(0, np.exp(-200)))
coefs = combos.mmsgnco(len(feats))
names = combos.name.index

# %%
thedh = dhlog
fname = 'x'
cols = []
for ii, c in enumerate(coefs):
    print(ii, '/', len(coefs))
    col = sum(thedh.iloc[:, i] * a for i, a in enumerate(c) if a != 0).astype(np.float32)
    col.name = fname + '.sgnint(' + names(c) + ')'
    cols += [col]
tots = pd.concat(cols, axis=1)
# Out:
# 0 / 1093
# 1 / 1093
# 2 / 1093
# 3 / 1093
# 4 / 1093
# 5 / 1093
# 6 / 1093
# 7 / 1093
# 8 / 1093
# 9 / 1093
# 10 / 1093
# 11 / 1093
# 12 / 1093
# 13 / 1093
# 14 / 1093
# 15 / 1093
# 16 / 1093
# 17 / 1093
# 18 / 1093
# 19 / 1093
# 20 / 1093
# 21 / 1093
# 22 / 1093
# 23 / 1093
# 24 / 1093
# 25 / 1093
# 26 / 1093
# 27 / 1093
# 28 / 1093
# 29 / 1093
# 30 / 1093
# 31 / 1093
# 32 / 1093
# 33 / 1093
# 34 / 1093
# 35 / 1093
# 36 / 1093
# 37 / 1093
# 38 / 1093
# 39 / 1093
# 40 / 1093
# 41 / 1093
# 42 / 1093
# 43 / 1093
# 44 / 1093
# 45 / 1093
# 46 / 1093
# 47 / 1093
# 48 / 1093
# 49 / 1093
# 50 / 1093
# 51 / 1093
# 52 / 1093
# 53 / 1093
# 54 / 1093
# 55 / 1093
# 56 / 1093
# 57 / 1093
# 58 / 1093
# 59 / 1093
# 60 / 1093
# 61 / 1093
# 62 / 1093
# 63 / 1093
# 64 / 1093
# 65 / 1093
# 66 / 1093
# 67 / 1093
# 68 / 1093
# 69 / 1093
# 70 / 1093
# 71 / 1093
# 72 / 1093
# 73 / 1093
# 74 / 1093
# 75 / 1093
# 76 / 1093
# 77 / 1093
# 78 / 1093
# 79 / 1093
# 80 / 1093
# 81 / 1093
# 82 / 1093
# 83 / 1093
# 84 / 1093
# 85 / 1093
# 86 / 1093
# 87 / 1093
# 88 / 1093
# 89 / 1093
# 90 / 1093
# 91 / 1093
# 92 / 1093
# 93 / 1093
# 94 / 1093
# 95 / 1093
# 96 / 1093
# 97 / 1093
# 98 / 1093
# 99 / 1093
# 100 / 1093
# 101 / 1093
# 102 / 1093
# 103 / 1093
# 104 / 1093
# 105 / 1093
# 106 / 1093
# 107 / 1093
# 108 / 1093
# 109 / 1093
# 110 / 1093
# 111 / 1093
# 112 / 1093
# 113 / 1093
# 114 / 1093
# 115 / 1093
# 116 / 1093
# 117 / 1093
# 118 / 1093
# 119 / 1093
# 120 / 1093
# 121 / 1093
# 122 / 1093
# 123 / 1093
# 124 / 1093
# 125 / 1093
# 126 / 1093
# 127 / 1093
# 128 / 1093
# 129 / 1093
# 130 / 1093
# 131 / 1093
# 132 / 1093
# 133 / 1093
# 134 / 1093
# 135 / 1093
# 136 / 1093
# 137 / 1093
; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)

# %%
raise Stop
test = dh[dh.Stock == 0][feats].iloc[140:150]
test = (np.random.randint(0, 100, size=test.shape) + test * 0).astype(int)

# %%
for i in range(7):
    test.iloc[i, i: i + i + 1] = np.nan
test
# Out:
#          x0    x1    x2    x3    x4    x5    x6
# Index
# 92340   NaN  20.0  60.0  42.0  19.0  55.0   3.0
# 92748  41.0   NaN   NaN   2.0   6.0  18.0  67.0
# 93159  51.0  22.0   NaN   NaN   NaN  24.0  80.0
# 93569  77.0  77.0  36.0   NaN   NaN   NaN   NaN
# 93981  54.0  43.0   3.0  98.0   NaN   NaN   NaN
# 94389  44.0  28.0  77.0   2.0  85.0   NaN   NaN
# 94808  46.0   7.0  78.0  60.0  75.0  14.0   NaN
# 95232  45.0  34.0  54.0  86.0  17.0  20.0  68.0
# 96076  97.0  15.0  10.0  90.0  53.0  42.0  20.0
# 96918   2.0  82.0  45.0  39.0   3.0  52.0   0.0

# %%
test.rolling(4, 1).mean().shift(1) # the mean of before not including up to
test.rolling(4, 1).mean().shift(-4) # the mean of after not including current
test.rolling(3, 3, center=True).mean() # the mean of after not including current
test.rolling(3, 3, center=True, win_type='triang').mean()
# Out:
#           x0     x1     x2     x3    x4     x5     x6
# Index
# 92340    NaN    NaN    NaN    NaN   NaN    NaN    NaN
# 92748    NaN    NaN    NaN    NaN   NaN  28.75  54.25
# 93159  55.00    NaN    NaN    NaN   NaN    NaN    NaN
# 93569  64.75  54.75    NaN    NaN   NaN    NaN    NaN
# 93981  57.25  47.75  29.75    NaN   NaN    NaN    NaN
# 94389  47.00  26.50  58.75  40.50   NaN    NaN    NaN
# 94808  45.25  19.00  71.75  52.00  63.0    NaN    NaN
# 95232  58.25  22.50  49.00  80.50  40.5  24.00    NaN
# 96076  60.25  36.50  29.75  76.25  31.5  39.00  27.00
# 96918    NaN    NaN    NaN    NaN   NaN    NaN    NaN

# %%
test.ewm(span=3, adjust=False).mean()
# Out:
#               x0         x1         x2     x3         x4         x5         x6
# Index
# 92340        NaN  20.000000  60.000000  42.00  19.000000  55.000000   3.000000
# 92748  41.000000  20.000000  60.000000  22.00  12.500000  36.500000  35.000000
# 93159  46.000000  21.333333  60.000000  22.00  12.500000  30.250000  57.500000
# 93569  61.500000  49.166667  40.800000  22.00  12.500000  30.250000  57.500000
# 93981  57.750000  46.083333  21.900000  82.80  12.500000  30.250000  57.500000
# 94389  50.875000  37.041667  49.450000  42.40  76.944444  30.250000  57.500000
# 94808  48.437500  22.020833  63.725000  51.20  75.972222  15.805556  57.500000
# 95232  46.718750  28.010417  58.862500  68.60  46.486111  17.902778  67.382353
# 96076  71.859375  21.505208  34.431250  79.30  49.743056  29.951389  43.691176
# 96918  36.929688  51.752604  39.715625  59.15  26.371528  40.975694  21.845588

# %%
thedh = dhlin
grp = dh.Stock
grpby = thedh.groupby(grp)
tots = []
_sym_ = '{}'
print('# flat and before')
for n in [1, 2, 3, 4, 5, 7, 9]:
    print(n)
    form = f'.window(<{n}>!{_sym_})'
    avg = grpby.apply(lambda x: x.rolling(n, 1).mean().shift(1))
    cnt = grpby.apply(lambda x: x.rolling(n, 1).count().shift(1))
    plus = (avg * cnt + thedh) / (cnt + 1)
    diff = thedh - avg
    ratio = thedh / avg
    guys = [df.astype(np.float32) for df in [plus, diff, ratio]]
    for df, sym in zip(guys, '+ - /'.split()):
        df.columns = [s + form.format(sym) for s in df.columns]
    tots += guys
print('# flat and after')
for n in [1, 2, 3, 4, 5, 7, 9]:
    print(n)
    form = f'.window(!<{n}>{_sym_})'
    avg = grpby.apply(lambda x: x.rolling(n, 1).mean().shift(-n))
    cnt = grpby.apply(lambda x: x.rolling(n, 1).count().shift(-n))
    plus = (avg * cnt + thedh) / (cnt + 1)
    diff = thedh - avg
    ratio = thedh / avg
    guys = [df.astype(np.float32) for df in [plus, diff, ratio]]
    for df, sym in zip(guys, '+ - /'.split()):
        df.columns = [s + form.format(sym) for s in df.columns]
    tots += guys
print('# flat and middle')
for n in [3, 5, 7, 9, 11]:
    print(n)
    form = f'.window(<<{n}>>{_sym_})'
    avg = grpby.apply(lambda x: x.rolling(n, 3, center=True).mean())
    cnt = grpby.apply(lambda x: x.rolling(n, 3, center=True).count())
    plus = avg + thedh * 0
    diff = (thedh - avg) * cnt / (cnt - 1)
    ratio = thedh / (thedh - diff)
    std = grpby.apply(lambda x: x.rolling(n, 3, center=True).std())
    stdr = thedh / std
    guys = [df.astype(np.float32) for df in [plus, diff, ratio, std, stdr]]
    for df, sym in zip(guys, '+ - / ~ ~/'.split()):
        df.columns = [s + form.format(sym) for s in df.columns]
    tots += guys
print('# triangle and middle')
for n in [3, 5, 7, 9, 11, 19]:
    print(n)
    form = f'.window(<^{n}^>{_sym_})'
    avg = grpby.apply(lambda x: x.rolling(n, 3, center=True, win_type='triang').mean())
    sum = grpby.apply(lambda x: x.rolling(n, 3, center=True, win_type='triang').sum())
    plus = avg + thedh * 0
    other = (sum - thedh) / (sum / avg - 1)
    diff = thedh - other
    ratio = thedh / other
    guys = [df.astype(np.float32) for df in [plus, diff, ratio]]
    for df, sym in zip(guys, '+ - /'.split()):
        df.columns = [s + form.format(sym) for s in df.columns]
    tots += guys
print('# exp and before')
for n in [2, 3, 4, 5, 7, 10, 15]:
    print(n)
    form = f'.window(<{n}>*!{_sym_})'
    alpha = 2 / (n + 1)
    avg = grpby.apply(lambda x: x.ewm(span=n, min_periods=1, adjust=False).mean().shift(1))
    plus = thedh * alpha + avg * (1 - alpha)
    diff = thedh - avg
    ratio = thedh / avg
    guys = [df.astype(np.float32) for df in [plus, diff, ratio]]
    for df, sym in zip(guys, '+ - /'.split()):
        df.columns = [s + form.format(sym) for s in df.columns]
    tots += guys
# Out:
# # flat and before
# 1
# 2
# 3
# 4
# 5
# 7
# 9
# # flat and after
# 1
# 2
# 3
# 4
# 5
# 7
# 9
# # flat and middle
# 3
# 5
# 7
# 9
# 11
# # triangle and middle
# 3
# 5
# 7
# 9
# 11
# 19
# # exp and before
# 2
# 3
# 4
# 5
# 7
# 10
# 15

# %%
thing = pd.concat(tots, axis=1)
thing.to_hdf(top_dir + '/data/features/x.window.hdf5', key='x.window')
# Out:
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/tables/path.py:112: NaturalNameWarning: object name is not a valid Python identifier: 'x.window'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning)
