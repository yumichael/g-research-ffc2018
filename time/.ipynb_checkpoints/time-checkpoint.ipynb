# %%
from common import *
from matrix import *
# %matplotlib inline
canvas(16, 9)

# %%
from statsmodels.tsa.stattools import acf
# Out:
# /home/ec2-user/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def_matrices(globals(), dhf)

# %%
CC = np.stack([acf(y, nlags=y.shape[0]) for y in Y.T.fillna(0).values], axis=1)
CC = pd.DataFrame(CC, columns=Y.columns)
CC.index.name = 'Lag'

# %%
plt.plot(CC.T.mean().T.values[:]);

# %%
_ = np.random.permutation(list(enumerate(CC.columns)))

# %%
C = O(MARKET=3, N_SAMPLES=1, COL_WRAP=3, HEIGHT=235, WIDTH=235)

for MARKET in [2]:
    data = dff[dff.Market == MARKET]
    stocks = random.sample(set(data.Stock), C.N_SAMPLES)
    data = dff[dff.Stock.isin(stocks)]
    data = data.copy()
    data.index = data.Day
    sig = data.y

# %%
sigg = sig.copy()
sigg[2] = np.nan

# %%
cc = acf(sig, nlags=260)
plt.plot(cc);
